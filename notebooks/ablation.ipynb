# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("bmh")
plt.rcParams["figure.figsize"] = (8, 6)
plt.rcParams["figure.dpi"]     = 150

# %%
df_guidance0 = pd.read_csv("../data/guidance_scale_0.0.csv")
df_guidance0.describe()
# Out:
#        Unnamed: 0    elapsed  refined_dice3d_0.0  refined_TP_0.0  \
# count        33.0  33.000000           33.000000       33.000000
# mean          0.0   2.936327            0.011880      161.363636
# std           0.0   0.097351            0.003228       44.068000
# min           0.0   2.805918            0.006205       84.000000
# 25%           0.0   2.850650            0.009146      124.000000
# 50%           0.0   2.955321            0.011786      160.000000
# 75%           0.0   2.978688            0.015440      210.000000
# max           0.0   3.264018            0.015878      216.000000
#
#        refined_FP_0.0  refined_FN_0.0  refined_TN_0.0  refined_chamfer_0.0  \
# count       33.000000            33.0            33.0            33.000000
# mean     26830.636364             0.0             8.0            17.454434
# std         44.068000             0.0             0.0             1.194031
# min      26776.000000             0.0             8.0            15.686952
# ...
